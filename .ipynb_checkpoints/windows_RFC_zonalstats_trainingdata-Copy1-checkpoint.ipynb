# %%
#### New attempt to classify, according to: https://gis.stackexchange.com/questions/373720/performing-supervised-classification-on-sentinel-images


from nansat import Nansat
from osgeo import gdal
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import scipy
from collections.abc import Iterable
from rasterstats import zonal_stats
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.decomposition import PCA
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

import matplotlib as mpl
mpl.use('Qt5Agg')
import matplotlib.pyplot as plt

# %%
s2_path = r'C:/Users/ariane/shared/NERSC/classification/subsets/'
rpoints = 'C:/Users/ariane/shared/NERSC/classification/rasterpoints.shp'
path = 'C:/Users/ariane/shared/NERSC/classification/'

# %%
df = gpd.read_file(rpoints) #Create geodataframe from the points

#Calulate statistic(s) for each point
for root, folders, files in os.walk(s2_path):
    for file in files:
        f = os.path.join(root, file)
        if os.path.isfile(f) and f.endswith('.tif'): #I use blue, green, red and infrared bands
            print(file)
            stats = ['max'] #Since we are using point files there's no reason for 'mean', 'median' 'std' etc...
            df2 = pd.DataFrame(zonal_stats(vectors=df['geometry'], raster=f, stats=stats))
            df2.columns=['{0}_{1}'.format(stat, file.split('.')[0]) for stat in stats]
            df = df.join(df2)
# Out:
# Subset_S2A_20210419_resampled.tif
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# Subset_S2A_20210509_resampled.tif
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# ...
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly
#
# C:\Users\ariane\anaconda3\envs\nansenproject2\lib\site-packages\rasterstats\io.py:313: UserWarning: Setting nodata to -999; specify nodata explicitly

# %%
df.columns.tolist()
# Out:
# ['classtxt',
#  'classid',
#  'B2',
#  'B3',
#  'B4',
#  'B8',
#  'B11',
#  'B12',
#  'NDVI',
#  'SAVI',
#  'MSAVI',
#  'NDMI',
#  'EVI',
#  'AWEI',
#  'NDWI',
#  'geometry',
#  'max_Subset_S2A_20210419_resampled',
#  'max_Subset_S2A_20210509_resampled',
#  'max_Subset_S2A_20210909_resampled',
#  'max_Subset_S2_20210419_resampled',
#  'max_Subset_S2_20210716_resampled']

# %%
#Split data into train and test (https://stackoverflow.com/questions/24147278/how-do-i-create-test-and-train-samples-from-one-dataframe-with-pandas)
msk = np.random.rand(len(df)) < 0.8
train = df[msk]
test = df[~msk]

#Train the model
predictor_cols = ['max_B2', 'max_B3', 'max_B4', 'max_B8', 'max_B11', 'max_B12']
X = train[predictor_cols].values.tolist() #List of lists: [64.0, 33.0, 41.0, 43.0] #X are the stats/predictor data
y = train['classid'].tolist() #y[:5]: [1, 1, 1, 1, 1] #y are the classes

clf = make_pipeline(StandardScaler(),
                    RandomForestClassifier(n_estimators = 100, n_jobs = -1, random_state=50)) 
clf.fit(X, y)

#Test
Xtest = test[predictor_cols]
ytest = test['classid']
p = clf.predict(Xtest)
clf.score(Xtest,ytest)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 8>()
#       6 #Train the model
#       7 predictor_cols = ['max_B2', 'max_B3', 'max_B4', 'max_B8', 'max_B11', 'max_B12']
# ----> 8 X = train[predictor_cols].values.tolist() #List of lists: [64.0, 33.0, 41.0, 43.0] #X are the stats/predictor data
#       9 y = train['classid'].tolist() #y[:5]: [1, 1, 1, 1, 1] #y are the classes
#      11 clf = make_pipeline(StandardScaler(),
#      12                     RandomForestClassifier(n_estimators = 100, n_jobs = -1, random_state=50))
#
# File ~\anaconda3\envs\nansenproject2\lib\site-packages\geopandas\geodataframe.py:1415, in GeoDataFrame.__getitem__(self, key)
#    1409 def __getitem__(self, key):
#    1410     """
#    1411     If the result is a column containing only 'geometry', return a
#    1412     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1413     return a GeoDataFrame.
#    1414     """
# -> 1415     result = super().__getitem__(key)
#    1416     geo_col = self._geometry_column_name
#    1417     if isinstance(result, Series) and isinstance(result.dtype, GeometryDtype):
#
# File ~\anaconda3\envs\nansenproject2\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\envs\nansenproject2\lib\site-packages\pandas\core\indexes\base.py:5796, in Index._get_indexer_strict(self, key, axis_name)
#    5793 else:
#    5794     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5796 self._raise_if_missing(keyarr, indexer, axis_name)
#    5798 keyarr = self.take(indexer)
#    5799 if isinstance(key, Index):
#    5800     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\envs\nansenproject2\lib\site-packages\pandas\core\indexes\base.py:5856, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5854     if use_interval_msg:
#    5855         key = list(key)
# -> 5856     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5858 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5859 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['max_B2', 'max_B3', 'max_B4', 'max_B8', 'max_B11', 'max_B12'], dtype='object')] are in the [columns]"
